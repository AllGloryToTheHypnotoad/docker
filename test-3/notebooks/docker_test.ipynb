# %%
# %matplotlib inline 

from __future__ import print_function, division
import numpy as np  # matrix manipulations
from matplotlib import pyplot as plt 
from math import pi, cos

# %%
x = range(100)
y = [3*cos(pi*i/10) for i in x]

# %%
plt.plot(x,y)
plt.grid(True)
